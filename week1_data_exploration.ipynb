# %% [markdown]
# # Week 1-2 Data Exploration and Python Exploration

# %% [markdown]
# ## Reading in the datasets

# %%
# Import libraries
import pandas as pd

# %%
# Read in datasets
listings_df = pd.read_csv('CRMLSListing202602.csv', encoding='ISO-8859-1')
sold_df = pd.read_csv('CRMLSSold202602.csv', encoding='ISO-8859-1')

# %%
listings_df.head()
# Out:
#    OriginalListPrice  ListingKey   CloseDate  ClosePrice ListAgentFirstName  \
# 0          1775000.0  1156313594         NaN         NaN              Diana
# 1          2900000.0  1156305330  2026-03-12   2900000.0              Molly
# 2           519000.0  1156298355         NaN         NaN               Hans
# 3          4698000.0  1156294964         NaN         NaN              Robyn
# 4          1100000.0  1156294960  2026-03-17   1100000.0              Hamid
#
#   ListAgentLastName   Latitude   Longitude           UnparsedAddress  \
# 0      Trinh-Salzer  34.181456 -119.232985        4575 Gateshead Bay
# 1           Fleming  32.988714 -117.263012           618 Sonrisa St.
# 2        Hagenmayer  34.258190 -118.326305   8780 1/2 Wyngate Street
# 3          Robinson  33.504678 -117.638115  31445 Juliana Farms Road
# 4           Koochak  34.016973 -118.368336       5625 Aladdin Street
#
#   PropertyType  ...  MainLevelBedrooms  NewConstructionYN  GarageSpaces  \
# ...

# %%
sold_df.head()
# Out:
#            BuyerAgentAOR           ListAgentAOR     Flooring ViewYN  \
# 0             HighDesert             HighDesert          NaN  False
# 1            ContraCosta                BayEast          NaN    NaN
# 2           OrangeCounty           OrangeCounty  Carpet,Tile  False
# 3  BeverlyHillsGreaterLa  BeverlyHillsGreaterLa         Wood  False
# 4               SanDiego               SanDiego          NaN    NaN
#
#   WaterfrontYN BasementYN PoolPrivateYN  OriginalListPrice  ListingKey  \
# 0          NaN        NaN         False          1850000.0  1156290692
# 1          NaN        NaN           NaN          1580000.0  1155696412
# 2          NaN        NaN         False          1100000.0  1155620121
# 3          NaN        NaN         False           999000.0  1155350576
# 4          NaN        NaN           NaN          1650000.0  1155221012
#
#     CloseDate  ...  MainLevelBedrooms NewConstructionYN GarageSpaces  \
# ...

# %%
print(f'Listing columns: \n{listings_df.columns} \n Sold columns: \n{sold_df.columns}')
# Out:
# Listing columns:
# Index(['OriginalListPrice', 'ListingKey', 'CloseDate', 'ClosePrice',
#        'ListAgentFirstName', 'ListAgentLastName', 'Latitude', 'Longitude',
#        'UnparsedAddress', 'PropertyType', 'LivingArea', 'ListPrice',
#        'DaysOnMarket', 'ListOfficeName', 'BuyerOfficeName', 'CoListOfficeName',
#        'ListAgentFullName', 'CoListAgentFirstName', 'CoListAgentLastName',
#        'BuyerAgentMlsId', 'BuyerAgentFirstName', 'BuyerAgentLastName',
#        'FireplacesTotal', 'AssociationFeeFrequency', 'AboveGradeFinishedArea',
#        'ListingKeyNumeric', 'MLSAreaMajor', 'TaxAnnualAmount',
#        'CountyOrParish', 'PropertyType.1', 'MlsStatus', 'ElementarySchool',
#        'ListAgentFirstName.1', 'AttachedGarageYN', 'ParkingTotal',
#        'BuilderName', 'PropertySubType', 'LotSizeAcres', 'SubdivisionName',
#        'BuyerOfficeAOR', 'YearBuilt', 'DaysOnMarket.1', 'StreetNumberNumeric',
# ...

# %%
listings_df.shape
# Out:
# (5000, 81)

# %%
sold_df.shape
# Out:
# (19081, 79)
